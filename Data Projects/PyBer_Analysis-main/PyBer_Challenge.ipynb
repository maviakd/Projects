# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "city_data.csv"
ride_data_to_load = "ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_Rides = pyber_data_df.groupby(['type']).count()['ride_id']
total_Rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_Drivers = city_data_df.groupby(['type']).sum()['driver_count']
total_Drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_Fares = pyber_data_df.groupby(['type']).sum()['fare']
total_Fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
average_Fare_per_ride = total_Fares / total_Rides
average_Fare_per_ride
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
average_Fare_per_Driver = total_Fares / total_Drivers
average_Fare_per_Driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_Summary_df = pd.DataFrame({"Total Rides": total_Rides, 
                                 "Total Drivers": total_Drivers,
                                 "Total Fares": total_Fares, 
                                 "Average Fare per Ride": average_Fare_per_ride, 
                                 "Average Fare per Driver": average_Fare_per_Driver})
pyber_Summary_df
# Out:
#           Average Fare per Driver  Average Fare per Ride  Total Drivers  \
# type
# Rural                   55.486282              34.623440             78
# Suburban                39.502714              30.970128            490
# Urban                   16.571468              24.525772           2405
#
#           Total Fares  Total Rides
# type
# Rural         4327.93          125
# Suburban     19356.33          625
# Urban        39854.38         1625

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_Summary_df.index.name = None
pyber_Summary_df
# Out:
#           Average Fare per Driver  Average Fare per Ride  Total Drivers  \
# Rural                   55.486282              34.623440             78
# Suburban                39.502714              30.970128            490
# Urban                   16.571468              24.525772           2405
#
#           Total Fares  Total Rides
# Rural         4327.93          125
# Suburban     19356.33          625
# Urban        39854.38         1625

# %%
#  8. Format the columns.
pyber_data_df
# Out:
#                      city                 date   fare        ride_id  \
# 0      Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1      South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2      Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3              Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4              South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5            South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6           New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7            Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8         South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9           North Jasmine  2019-03-09 06:26:29  42.81  5327642267789
# 10    New Kimberlyborough  2019-02-07 01:10:11   9.34  7992781920789
# 11            West Angela  2019-01-12 01:45:27  26.86  4820052223501
# 12             Rodneyfort  2019-03-02 18:03:20  44.26  2494064867705
# 13            West Angela  2019-01-10 12:17:31  12.74  2108723916092
# 14            Roberthaven  2019-05-04 14:48:56  25.66  1026197778354
# 15            North Jason  2019-03-28 22:28:44   9.19  7007022521141
# 16           Williamsview  2019-01-03 16:19:25  18.93  1979492913169
# 17                Leahton  2019-02-26 18:42:15   8.85  6966668662612
# 18           West Anthony  2019-03-06 02:27:01  10.02  9396763280782
# 19    New Kimberlyborough  2019-04-25 22:58:38  29.67  4823568522144
# 20            Roberthaven  2019-02-24 10:26:34   7.80  2180566685151
# 21            New Paulton  2019-05-01 03:12:49   8.28  8527101897862
# 22    West Patrickchester  2019-03-19 05:46:20  40.86   898889456779
# 23              Deanville  2019-04-25 03:29:09  41.52  6055928921559
# 24        West Josephberg  2019-02-19 16:22:09  36.39  3322126516683
# 25       West Samuelburgh  2019-05-03 14:33:41  41.12  7330842806458
# 26             West Heidi  2019-03-14 23:46:50  24.40  4908573010166
# 27              Loganberg  2019-04-01 01:06:03   8.23   678728883160
# 28            Huntermouth  2019-02-10 23:32:13  25.79  1880379662035
# 29           South Latoya  2019-01-11 18:44:14  27.41  8662301917375
# ...                   ...                  ...    ...            ...
# 2345         West Heather  2019-02-04 16:29:23  13.97  7118893881453
# 2346         West Heather  2019-04-18 19:33:12  46.60  3671003215967
# 2347         West Heather  2019-03-02 21:04:10  20.99  5766454453070
# 2348      South Saramouth  2019-01-28 15:55:33  31.25  7118046558393
# 2349         West Heather  2019-03-06 20:06:51  48.11  2570548892682
# 2350            Garzaport  2019-05-06 16:57:16  18.90  8826696981094
# 2351      South Saramouth  2019-03-27 21:07:16  11.87   170351888128
# 2352       Randallchester  2019-04-07 23:42:07  10.79  1615474447641
# 2353       Harringtonfort  2019-01-09 15:30:35  31.84  3730685356921
# 2354      South Saramouth  2019-04-12 18:11:50  57.23  5081198789583
# 2355          North Holly  2019-01-03 19:51:01  19.90  5559509612597
# 2356         New Ryantown  2019-05-05 19:29:38  26.53  2302209966018
# 2357         West Heather  2019-02-02 06:28:04  53.07  2462950442268
# 2358      Lake Latoyabury  2019-02-25 04:10:19  16.18  8492924830016
# 2359    South Marychester  2019-01-19 11:40:46  49.44    90058815985
# 2360          Jessicaport  2019-01-31 17:57:25  58.29   623154556195
# 2361          Michaelberg  2019-03-22 22:20:54  38.30  8032727406577
# 2362          North Holly  2019-04-18 19:26:25  30.94  3441061016826
# 2363          Michaelberg  2019-03-13 14:40:18  37.72  8842606115175
# 2364           Lake Jamie  2019-02-25 23:46:02  28.65  5815763839331
# 2365           Lake Jamie  2019-04-19 04:32:47  16.29  3518682119233
# 2366          North Holly  2019-03-18 10:38:05  40.34  3787775176860
# 2367          Michaelberg  2019-01-27 18:43:05  38.42   862622008020
# 2368           Lake Jamie  2019-04-29 01:58:44  54.22  2489264790267
# 2369         Bradshawfurt  2019-01-30 10:55:23  51.39  1328274868072
# 2370          Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371      Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372          North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373         West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374           Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# 4               46  Urban
# 5               10  Urban
# 6               44  Urban
# 7               21  Urban
# 8                4  Urban
# 9               33  Urban
# 10              33  Urban
# 11              48  Urban
# 12              34  Urban
# 13              48  Urban
# 14              47  Urban
# 15               6  Urban
# 16              46  Urban
# 17              17  Urban
# 18              70  Urban
# 19              33  Urban
# 20              47  Urban
# 21              44  Urban
# 22              25  Urban
# 23              49  Urban
# 24              45  Urban
# 25              73  Urban
# 26              28  Urban
# 27              23  Urban
# 28              37  Urban
# 29              10  Urban
# ...            ...    ...
# 2345             4  Rural
# 2346             4  Rural
# 2347             4  Rural
# 2348             7  Rural
# 2349             4  Rural
# 2350             7  Rural
# 2351             7  Rural
# 2352             9  Rural
# 2353             4  Rural
# 2354             7  Rural
# 2355             8  Rural
# 2356             2  Rural
# 2357             4  Rural
# 2358             2  Rural
# 2359             1  Rural
# 2360             1  Rural
# 2361             6  Rural
# 2362             8  Rural
# 2363             6  Rural
# 2364             4  Rural
# 2365             4  Rural
# 2366             8  Rural
# 2367             6  Rural
# 2368             4  Rural
# 2369             7  Rural
# 2370             6  Rural
# 2371             2  Rural
# 2372             1  Rural
# 2373             4  Rural
# 2374             1  Rural
#
# [2375 rows x 6 columns]

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head(20)
# Out:
#                    city                 date   fare        ride_id  \
# 0    Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1    South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2    Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3            Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4            South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5          South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6         New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7          Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8       South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9         North Jasmine  2019-03-09 06:26:29  42.81  5327642267789
# 10  New Kimberlyborough  2019-02-07 01:10:11   9.34  7992781920789
# 11          West Angela  2019-01-12 01:45:27  26.86  4820052223501
# 12           Rodneyfort  2019-03-02 18:03:20  44.26  2494064867705
# 13          West Angela  2019-01-10 12:17:31  12.74  2108723916092
# 14          Roberthaven  2019-05-04 14:48:56  25.66  1026197778354
# 15          North Jason  2019-03-28 22:28:44   9.19  7007022521141
# 16         Williamsview  2019-01-03 16:19:25  18.93  1979492913169
# 17              Leahton  2019-02-26 18:42:15   8.85  6966668662612
# 18         West Anthony  2019-03-06 02:27:01  10.02  9396763280782
# 19  New Kimberlyborough  2019-04-25 22:58:38  29.67  4823568522144
#
#     driver_count   type
# 0              5  Urban
# 1             72  Urban
# 2             57  Urban
# 3             34  Urban
# 4             46  Urban
# 5             10  Urban
# 6             44  Urban
# 7             21  Urban
# 8              4  Urban
# 9             33  Urban
# 10            33  Urban
# 11            48  Urban
# 12            34  Urban
# 13            48  Urban
# 14            47  Urban
# 15             6  Urban
# 16            46  Urban
# 17            17  Urban
# 18            70  Urban
# 19            33  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
pyber_Pivot_df = pyber_data_df.groupby(['date', 'type']).sum()[['fare']]
pyber_Pivot_df.head(10)
# Out:
#                                fare
# date                type
# 2019-01-01 00:08:16 Urban     37.91
# 2019-01-01 00:46:46 Suburban  47.74
# 2019-01-01 02:07:24 Suburban  24.07
# 2019-01-01 03:46:50 Urban      7.57
# 2019-01-01 05:23:21 Urban     10.75
# 2019-01-01 09:45:36 Rural     43.69
# 2019-01-01 12:32:48 Suburban  25.56
# 2019-01-01 14:40:14 Urban      5.42
# 2019-01-01 14:42:25 Urban     12.31
# 2019-01-01 14:52:06 Suburban  31.15

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
pyber_Pivot_df = pyber_Pivot_df.reset_index()
pyber_Pivot_df
# Out:
#                      date      type   fare
# 0     2019-01-01 00:08:16     Urban  37.91
# 1     2019-01-01 00:46:46  Suburban  47.74
# 2     2019-01-01 02:07:24  Suburban  24.07
# 3     2019-01-01 03:46:50     Urban   7.57
# 4     2019-01-01 05:23:21     Urban  10.75
# 5     2019-01-01 09:45:36     Rural  43.69
# 6     2019-01-01 12:32:48  Suburban  25.56
# 7     2019-01-01 14:40:14     Urban   5.42
# 8     2019-01-01 14:42:25     Urban  12.31
# 9     2019-01-01 14:52:06  Suburban  31.15
# 10    2019-01-01 17:22:58     Urban  42.11
# 11    2019-01-01 21:04:01     Urban  11.71
# 12    2019-01-02 00:13:08  Suburban  44.71
# 13    2019-01-02 00:44:03     Urban  43.72
# 14    2019-01-02 00:56:53     Urban  37.34
# 15    2019-01-02 01:41:26  Suburban  49.95
# 16    2019-01-02 01:46:40     Urban  34.79
# 17    2019-01-02 06:55:36     Urban  16.96
# 18    2019-01-02 07:26:53  Suburban  33.57
# 19    2019-01-02 09:28:27     Urban  19.81
# 20    2019-01-02 09:57:04     Urban  33.06
# 21    2019-01-02 11:18:32     Rural  52.12
# 22    2019-01-02 11:51:32     Urban   7.45
# 23    2019-01-02 14:14:50     Urban  13.89
# 24    2019-01-02 15:38:25  Suburban  45.32
# 25    2019-01-02 16:22:46  Suburban  47.07
# 26    2019-01-02 16:59:55  Suburban  33.62
# 27    2019-01-02 17:52:38  Suburban  20.68
# 28    2019-01-02 20:08:57     Urban  10.19
# 29    2019-01-02 20:52:31     Urban  33.08
# ...                   ...       ...    ...
# 2345  2019-05-07 01:03:12     Urban  12.35
# 2346  2019-05-07 02:49:39  Suburban  15.41
# 2347  2019-05-07 02:52:22     Urban  36.51
# 2348  2019-05-07 05:55:00     Urban   6.89
# 2349  2019-05-07 07:08:15  Suburban  20.52
# 2350  2019-05-07 08:47:24     Urban  25.83
# 2351  2019-05-07 10:11:06     Urban  29.66
# 2352  2019-05-07 11:23:59     Urban  22.72
# 2353  2019-05-07 12:25:01     Urban   4.47
# 2354  2019-05-07 12:30:58     Urban  34.03
# 2355  2019-05-07 12:33:26  Suburban  21.72
# 2356  2019-05-07 13:29:36  Suburban  38.74
# 2357  2019-05-07 13:31:26  Suburban  42.48
# 2358  2019-05-07 14:00:13  Suburban  26.30
# 2359  2019-05-07 14:38:35  Suburban  13.05
# 2360  2019-05-07 14:58:12     Urban  36.22
# 2361  2019-05-07 15:34:59  Suburban  44.87
# 2362  2019-05-07 17:27:48     Urban   6.39
# 2363  2019-05-07 19:22:15     Rural  44.94
# 2364  2019-05-07 19:45:40  Suburban  26.11
# 2365  2019-05-07 20:05:15     Urban  24.20
# 2366  2019-05-07 20:22:19     Urban  18.74
# 2367  2019-05-07 20:40:29  Suburban  24.89
# 2368  2019-05-08 01:54:18     Urban  32.69
# 2369  2019-05-08 02:31:25     Urban  41.33
# 2370  2019-05-08 04:20:00     Urban  21.99
# 2371  2019-05-08 04:39:49     Urban  18.45
# 2372  2019-05-08 07:29:01     Urban  18.55
# 2373  2019-05-08 11:38:35     Urban  19.77
# 2374  2019-05-08 13:10:18     Urban  18.04
#
# [2375 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
pyber_Pivot_df = pyber_Pivot_df.pivot(index='date', columns='type', values='fare')
pyber_Pivot_df.head(20)
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# 2019-01-01 09:45:36  43.69       NaN    NaN
# 2019-01-01 12:32:48    NaN     25.56    NaN
# 2019-01-01 14:40:14    NaN       NaN   5.42
# 2019-01-01 14:42:25    NaN       NaN  12.31
# 2019-01-01 14:52:06    NaN     31.15    NaN
# 2019-01-01 17:22:58    NaN       NaN  42.11
# 2019-01-01 21:04:01    NaN       NaN  11.71
# 2019-01-02 00:13:08    NaN     44.71    NaN
# 2019-01-02 00:44:03    NaN       NaN  43.72
# 2019-01-02 00:56:53    NaN       NaN  37.34
# 2019-01-02 01:41:26    NaN     49.95    NaN
# 2019-01-02 01:46:40    NaN       NaN  34.79
# 2019-01-02 06:55:36    NaN       NaN  16.96
# 2019-01-02 07:26:53    NaN     33.57    NaN
# 2019-01-02 09:28:27    NaN       NaN  19.81

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
pyber_Pivot_df = pyber_Pivot_df.loc['2019-01-01':'2019-04-29']
pyber_Pivot_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# 2019-01-01 09:45:36  43.69       NaN    NaN
# 2019-01-01 12:32:48    NaN     25.56    NaN
# 2019-01-01 14:40:14    NaN       NaN   5.42
# 2019-01-01 14:42:25    NaN       NaN  12.31
# 2019-01-01 14:52:06    NaN     31.15    NaN
# 2019-01-01 17:22:58    NaN       NaN  42.11
# 2019-01-01 21:04:01    NaN       NaN  11.71
# 2019-01-02 00:13:08    NaN     44.71    NaN
# 2019-01-02 00:44:03    NaN       NaN  43.72
# 2019-01-02 00:56:53    NaN       NaN  37.34
# 2019-01-02 01:41:26    NaN     49.95    NaN
# 2019-01-02 01:46:40    NaN       NaN  34.79
# 2019-01-02 06:55:36    NaN       NaN  16.96
# 2019-01-02 07:26:53    NaN     33.57    NaN
# 2019-01-02 09:28:27    NaN       NaN  19.81
# 2019-01-02 09:57:04    NaN       NaN  33.06
# 2019-01-02 11:18:32  52.12       NaN    NaN
# 2019-01-02 11:51:32    NaN       NaN   7.45
# 2019-01-02 14:14:50    NaN       NaN  13.89
# 2019-01-02 15:38:25    NaN     45.32    NaN
# 2019-01-02 16:22:46    NaN     47.07    NaN
# 2019-01-02 16:59:55    NaN     33.62    NaN
# 2019-01-02 17:52:38    NaN     20.68    NaN
# 2019-01-02 20:08:57    NaN       NaN  10.19
# 2019-01-02 20:52:31    NaN       NaN  33.08
# ...                    ...       ...    ...
# 2019-04-27 12:41:46    NaN       NaN  18.99
# 2019-04-27 14:11:38    NaN       NaN  37.60
# 2019-04-27 14:37:32    NaN     45.77    NaN
# 2019-04-27 14:57:38    NaN       NaN  44.73
# 2019-04-27 16:20:00    NaN       NaN   6.62
# 2019-04-27 16:22:23    NaN       NaN  25.67
# 2019-04-27 17:58:27  14.01       NaN    NaN
# 2019-04-27 19:45:48    NaN     28.84    NaN
# 2019-04-27 20:41:36    NaN       NaN   8.28
# 2019-04-27 23:26:03    NaN       NaN  19.06
# 2019-04-27 23:52:44    NaN     45.98    NaN
# 2019-04-28 00:26:35    NaN       NaN   5.42
# 2019-04-28 00:56:58    NaN     26.61    NaN
# 2019-04-28 02:38:11    NaN       NaN  39.41
# 2019-04-28 04:00:40    NaN       NaN  39.82
# 2019-04-28 04:21:34    NaN     27.86    NaN
# 2019-04-28 04:34:56    NaN       NaN  40.46
# 2019-04-28 08:15:09    NaN       NaN  22.86
# 2019-04-28 09:03:54    NaN       NaN  15.00
# 2019-04-28 09:10:04    NaN       NaN   5.73
# 2019-04-28 09:25:03    NaN       NaN  37.35
# 2019-04-28 10:54:14    NaN       NaN  10.07
# 2019-04-28 11:40:49    NaN     43.22    NaN
# 2019-04-28 11:49:26    NaN     39.19    NaN
# 2019-04-28 12:48:34    NaN       NaN  33.35
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
pyber_Pivot_df.index = pd.to_datetime(pyber_Pivot_df.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
pyber_Pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2196 entries, 2019-01-01 00:08:16 to 2019-04-28 19:35:03
# Data columns (total 3 columns):
# Rural       114 non-null float64
# Suburban    573 non-null float64
# Urban       1509 non-null float64
# dtypes: float64(3)
# memory usage: 68.6 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
pyber_Sum_Fares_Week = pyber_Pivot_df.resample("W").sum()
pyber_Sum_Fares_Week
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

pyber_Sum_Fares_Week.plot(figsize=(25, 7), kind='line')
plt.ylabel('Fare($USD)', fontsize='20')
plt.ylim(0, 2550)
plt.yticks(fontsize='16')
plt.xticks(fontsize='16')
plt.title('Total Fare by City Type', fontsize='30')

# Import the style from Matplotlib.
from matplotlib import style

# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

plt.savefig("PyBer_Fare_Summary.png")
